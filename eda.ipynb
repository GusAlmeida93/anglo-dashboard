# %%
import pandas as pd
import os
from office365.runtime.auth.authentication_context import AuthenticationContext
from office365.sharepoint.client_context import ClientContext
from office365.sharepoint.files.file import File

# %%
user = os.environ['user']
password = os.environ['password']
site_url = os.environ['site_url']
relative_url_to_file = os.environ['relative_url_to_file']

# %%
ctx_auth = AuthenticationContext(site_url)
if ctx_auth.acquire_token_for_user(user, password):
    ctx = ClientContext(site_url, ctx_auth)
    
    
    response = File.open_binary(ctx, relative_url_to_file)

    # Instead of file.read(), use response.content to get the binary content of the file
    with open("data.xlsx", "wb") as local_file:
        local_file.write(response.content)
else:
    print(ctx_auth.get_last_error())

# %%
df = pd.read_excel('data.xlsx', sheet_name='Form1')

# %%
df
# Out:
#    ID          Start time     Completion time                         Email  \
# 0   1 2023-08-04 20:30:00 2023-08-04 20:30:33  A238144@somoseducacao.com.br
# 1   2 2023-08-04 20:44:32 2023-08-04 20:45:23  A238144@somoseducacao.com.br
#
#                             Name  Last modified time       DATA PLANTÃO  \
# 0  Aline Isabela Paulino Pereira                 NaN 2023-08-04  ONLINE
# 1  Aline Isabela Paulino Pereira                 NaN 2023-08-04  ONLINE
#
#   UNIDADE DO ALUNO  CURSOS PAULISTA\n  ...  \
# 0         PAULISTA                NaN  ...
# 1             PLAY                NaN  ...
#
#    TEORIA - PALAVRA-CHAVE/CONCEITO/BREVE RESUMO - (História)  \
# 0                                                NaN
# 1                                                NaN
#
#   ERRO DE GABARITO (História)\nIndicar o caderno em que o erro aparece, número da página e número da questão   \
# 0                                                NaN
# ...
